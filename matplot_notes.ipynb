# %% [markdown]
# 1. Line Plot (plt.plot())
#
# Trends over time
#
# Loss during training, learning curves
#
# 2. Scatter Plot (plt.scatter())
#
# Data points in 2D
#
# Visualize relationships, clusters
#
# 3. Bar Chart (plt.bar())
#
# Categorical comparisons
#
# Compare accuracy of models or classes
#
# 4. Histogram (plt.hist())
#
# Distribution of values
#
# See data spread, skew, outliers
#
# 5. Box Plot (sns.boxplot())
#
# Distribution + outliers
#
# Clean way to compare distributions
#
# 6. Heatmap (sns.heatmap())
#
# Matrix of values
#
# Correlation matrix, confusion matrix
#
# 7. Confusion Matrix (sklearn.metrics.ConfusionMatrixDisplay)
#
# Prediction performance
#
# Shows how your classifier performed
#
# 8. ROC Curve / AUC (sklearn.metrics.roc_curve)
#
# Binary classifier strength
#
# Trade-off between TPR and FPR
#
# 9. Pair Plot (sns.pairplot())
#
# Multi-feature scatter plots
#
# Feature relationships for clustering or classification
#
# 10. Loss & Accuracy Curve
#
#
# for drugdesign or ml.
#
#  Dose-Response Curve (sigmoid)
#
# Used in EC50/IC50 curve fitting
#
# 📦 Violin Plot
#
# Compare compound activity distributions
#
# 🧬 Molecule Similarity Heatmap

# %% [markdown]
# ### Introduction to basic Matplotlib ###
#
# **Matplotlib** is a popular python library for visualization of data.
#
# it is widely used in scientific computing , machine learning and data analysis.
#
# the main module is pyplot, usaully imported as
#  ```python
# import matplotlib.pyplot as plt
#
# ```
#  **Basic plotting**
#
# 1. Line plotting

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
plt.plot(a,b,)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(visible=True)
plt.title("Simple Line Plot")
plt.legend(["Line 1"])
plt.show()

# %% [markdown]
# **Explanation of each functions and sub-modules**
#
# there are many sub-modules for matplotlib, but we are going through pyplot only for now.
#
# pyplot is imported as plt for writing easily.
#
# their are many functions which comes uder plt or pyplot.
#
# 1. plt.plot(x,y,fmt,**kargs)
#
# this is plot function,  x and y represent data points of arrays or list
#
# **fmt - is called format string**
#
# - Control color, marker, and line style with shorthand notation:
#
# - Color: 'r' (red), 'b' (blue), 'g' (green), etc.
#
# - Marker: 'o' (circles), 's' (squares), '.' (dots).
#
# - Line: '-' (solid), '--' (dashed), ':' (dotted).
#
# for example if we use 'ro--' it means red circled dashed line: note: it should be inside one
#
# mark string '', -- is **not** underscore.

# %%
plt.plot(a,b,'ro--')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(visible=True)
plt.title("Simple Line Plot with Red Dots") 
plt.legend(["Line 1 with Red Dots"])
plt.show()

# %% [markdown]
# #### Keyword Arguments (**kwargs) ####
#
# **Customize further:**
#
# linewidth or lw: Line thickness.
#
# markersize or ms: Marker size.
#
# label: For legends.
#
# alpha: Transparency (0 to 1).

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.plot([1,2,3,4],[5,6,7,8],'-b',markersize=2,linewidth=5,alpha=.5)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(visible=True)
plt.show()

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, 'g-' ,label='sin(x)',linewidth=2) 
plt.title("Customized Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend() # this function is needed to show the label which is written in the plot function
plt.grid(True, linestyle=':', alpha=0.5) #look at the grid in : style with 50% transparency
plt.show()

# %% [markdown]
# go through this example to learn other arguments of function

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
plt.plot(x, [4, 5, 1], label='Dataset A')
plt.plot(x, [2, 3, 4], label='Dataset B')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Comparison Plot")
plt.legend()
plt.grid(True, linestyle=':', alpha=0.5)
plt.show()

# %% [markdown]
# **scatter ploting**
#
# we can plot like point wise, it's good for svm .
#
# the general syntax is
# ```python
# xplt.scatter(x, y, s=100)
#
# ```
# s is the dot size

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(50)
y1=np.random.rand(50)
y2=np.random.rand(50)

plt.scatter(x,y1,c='b',label='dataset y1',edgecolor='r',linewidth=1,alpha=.5,s=10) 
plt.scatter(x,y2,c='g',label='dataset y2',edgecolor='b',linewidth=1,alpha=.5,s=20)
plt.grid(True)
plt.legend()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# it's better to just put the cursor inside the function as their are too much customization.
#
# basic scatter function.You may wonder why we need 3 arrays but only 2 datasets?
#
#  x serves as the common independent variable (or coordinate) for both scatter plots, while
#
#  y1 and y2 are two different dependent variables being compared against the same x values.

# %% [markdown]
# In plt.plot(), "b-" means:
#
# 	•	b: blue color
#
# 	•	-: solid line
#
# But plt.scatter() does not use style strings like "b-" or "g-".

# %% [markdown]
# **Bar Chart**
#
# here we represent data through bar chart.

# %%
import matplotlib.pyplot as plt

categories=['a','b','c','d','e']
dataset=[1,2,3,4,5]
plt.bar(categories,dataset,color='skyblue',label='hello')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("bar graph")
plt.legend()
plt.show()

# %%
plt.barh(categories,dataset,color='red',label='hihi')
plt.title("horizontal bar-graph")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %% [markdown]
# **Grouped bar-chart**
#
# multiple bars per category.
#
# You use a grouped bar chart when:
#
# 	•	You have data categorized by two categorical variables.
#
# 	•	You want to compare subgroups within a main category.

# %%
import numpy as np

# Data
labels = ['Group 1', 'Group 2', 'Group 3']
men = [29, 35, 30]
women = [25, 32, 34]

x = np.arange(len(labels))  # Label positions
width = .1  # Bar width

# Plot bars
plt.bar(x - width/2, men, width, label='Men', color='blue')
plt.bar(x + width/2, women, width, label='Women', color='pink')

# Customize
plt.title("Grouped Bar Chart")
plt.xlabel("Groups")
plt.ylabel("Scores")
plt.xticks(x, labels)
plt.legend()

plt.show()

# %% [markdown]
# ```python
# import numpy as np
# np.arange(5)
#
# output-array([0, 1, 2, 3, 4])

# %% [markdown]
# What Happens?
#
# plt.xticks(x, labels) does two things at once:
#
# Sets the tick positions (x).
#
# Sets the tick labels (labels).
#
# ```python
# fig, ax = plt.subplots()
# ax.bar(x, [10, 20, 15])       # Plot on the Axes object
# ax.set_xticks(x)              # Set tick positions
# ax.set_xticklabels(labels)    # Set tick labels
# plt.show()
# ```
# but
# ```python
#  plt.xticks(x,labels )
#  ax.set_xticks(x)
#  #gives the same results as
# ax.set_xticklabels(labels)

# %% [markdown]
# **Ploting using Histogram**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data (1000 values, normally distributed)
data = np.random.randn(1000)  # Gaussian (normal) distribution

# Create a histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Basic Histogram Example')

# Display the plot
plt.show()

# %%
# Generate two datasets
data1 = np.random.normal(0, 1, 1000)  # Mean=0, Std=1
data2 = np.random.normal(3, 1.5, 1000)  # Mean=3, Std=1.5

# Plot both histograms
plt.hist(data1, bins=30, alpha=0.5, label='Dataset 1', color='blue',edgecolor='black')
plt.hist(data2, bins=30, alpha=0.5, label='Dataset 2', color='red',edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Comparing Two Distributions')
plt.legend()  # Show legend
plt.show()

# %% [markdown]
# to save the histogram image
# ```python
# plt.hist(data, bins=30, color='purple')
# plt.title('Saved Histogram')
# plt.savefig('histogram.png')  # Saves as PNG
# plt.show()

# %% [markdown]
# other than matplotlib plotly express can also be used for better visualization, the output
#
# can be interacted in plotly but in matplotlib it is just a static image.
#
# for example:

# %%
import pandas as pd
url="https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/refs/heads/master/insurance.csv"
df=pd.read_csv(url)

# %%
import plotly.express as px
fig=px.histogram(df,x='age',marginal='box',nbins=50,title='histogram representation of age')
#Use df['age'] for matplotlib.
#Use df, x='age' for Plotly Express.
fig.update_layout(bargap=.1)
fig.show()

# %% [markdown]
# f you use df['age'] directly, Plotly treats it as a Series, not a DataFrame, so you can't
#
# use column names or other DataFrame features (like grouping, color, etc.). Passing the
#
# DataFrame allows Plotly to access all columns and metadata, making it more flexible for
#
# advanced plots.
#
# Summary:
#
# Use df['age'] for matplotlib.
#
# Use df, x='age' for Plotly Express.
#
# n Plotly Express histograms, the marginal argument adds extra plots to the histogram for
#
# additional context. The available types for marginal are:
#
# "rug": Adds a rug plot (small vertical lines) showing individual data points.
#
# "box": Adds a box plot summarizing the distribution.
#
# "violin": Adds a violin plot showing the distribution's density.
#
# "histogram": Adds a smaller histogram above or beside the main plot.
#
# None: No marginal plot (default).
#
# **output explanation**
# Median: The line inside the box; it divides the data into two equal halves.
#
# Q1 (First Quartile): The left (or bottom) edge of the box; 25% of data is below this value.
#
# Q3 (Third Quartile): The right (or top) edge of the box; 75% of data is below this value.
#
# Interquartile Range (IQR): The width of the box; calculated as Q3 - Q1.
#
# Whiskers (Fences): Lines extending from the box to the smallest and largest values within 1.
#
# 5 × IQR from Q1 and Q3.
#
# Outliers: Points outside the whiskers.

# %%
import plotly.express as px

# Scatter plot: Age vs Charges, colored by smoker status
fig = px.scatter(
    df,
    x='age',           # x-axis: age of customer
    y='charges',       # y-axis: medical charges
    color='smoker',    # color points by smoker status
    title='Age vs Charges by Smoker Status'
)
fig.show()

# %% [markdown]
# In Plotly Express, color='smoker' means the points are colored based on the values in the
#
# 'smoker' column, automatically assigning different colors for each category (e.g., 'yes' or
#
# 'no'). This helps visualize group differences.
#
# In matplotlib, you cannot use color='smoker' because matplotlib expects a color name (like
#
# 'red', 'blue') or a list/array of colors, not a column name. Matplotlib does not
#
# automatically map column values to colors.
#
# Summary:
#
# color='column' works in Plotly Express for automatic grouping.
#
# In matplotlib, use explicit color names or arrays, not column names.

# %%
#now we can plot bmi vs health charges of smoker or non smoker using scatter
fig=px.scatter(df,x='bmi',y='charges',color='smoker',
               title='bmi vs smocker charges')

fig.show()

# %%
#now we are generating bmi vs age using scatter plot
fig=px.scatter(df,x='age',y='bmi',title='bmi vs age plot',color='sex')
fig.show()

# %% [markdown]
# here we got some random things without any pattern, so may be their is
#
# no relation between male,female,age and bmi.
#
# but from previous output we can conclude smocking has an effect in
#
# hospital charges.

# %% [markdown]
# just for experements we are going to test if there any corelation
#
# between gender and hospital charges.

# %%
#checking relation between gender and hospital charges

fig=px.scatter(df,y='charges',color='sex',
               title='gender vs hospital charges')
fig.show()

# %% [markdown]
# so from output it is cxlear that no corelation between gender and
#
# hospital charges

# %%
# Count number of smokers ('yes') in each region
import plotly.express as px

smoker_counts = df[df['smoker'] == 'yes'].groupby('region').size().reset_index(name='count')

fig = px.bar(smoker_counts, x='region', y='count', title='Number of Smokers by Region')
fig.show()

# %%
import matplotlib.pyplot as plt

# Count number of smokers ('yes') in each region
smoker_counts = df[df['smoker'] == 'yes'].groupby('region').size()

# Plot bar chart
plt.bar(smoker_counts.index, smoker_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Number of Smokers')
plt.title('Number of Smokers by Region')
plt.show()
